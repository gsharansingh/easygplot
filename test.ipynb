# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from easygplot import read, Plot
mydata = read.CSV("gasprices.csv")
# Out:
# Data contains missing values. Here is the representation of missing values:
# NOTE: if the data has whole row or column as missing values, that row or column is already dropped!
# For more information, check 'missing_data_handling_strategy' parameter in Docu String by: 'print(easygplot.read.CSV.__doc__)'

# %%
plot = Plot.Subplots(sample= mydata[:], legend = True)
plot('all')

# %%
plot = Plot.Subplots(sample= mydata[:], legend = True)
plot('line', 'box', 'pie', 'bar', 'histogram')

# %%
line_plot = Plot.Line(legend=True)
a = line_plot(mydata[:])
line_plot2 = Plot.Line(mydata[:], legend = True)
a2 = line_plot()
bar_plot = Plot.Bar(legend=True)
b = bar_plot(mydata[:])

# %%
c = Plot.Line(legend=True)(mydata[1])

# %%
from torchvision import transforms
plot_obj = transforms.Compose([Plot.Line(legend=True), Plot.Bar(legend=True), Plot.Box(), Plot.Histogram(legend=True), Plot.Pie(legend=True)])
d = plot_obj(mydata[:])

# %%
e = Plot.Pie(legend=True)(mydata[:])

# %%
plot_line = Plot.Box( title = 'Gas Prices', y_label = 'Prices($/barrel)', x_label = "Countries")
f = plot_line(mydata[:])

# %%
plot_line = Plot.Pie(legend = True, title_cwise = "Price difference in Countries (Accumulated)")
f = plot_line(mydata[:])

# %%
print(Plot.Line.__doc__)
# Out:
#     This module helps in plotting Line Graph on a csv file read by 'easygplot.read(...filename...)'
#     Parameters
#     ----------
#     sample : 'easygplot.read.CSV(...filename...)' object, optional (if the object will be passed while calling the object this class)
#         Pass the data and labels read by the 'easygplot.read(...filename...)'.
#     figsize : tuple, optional (default = (8, 5))
#         first and second element in tuple represent the dimensions of the line graph, which are
#         width and height respectivily.
#     linestyle : str (default = 'solid')
#         Set the linestyle of the line
#         '-' or 'solid'     =>   solid line
#         '--' or 'dashed'   =>   dashed line
#         '-.' or 'dashdot'  =>	dash-dotted line
#         ':' or 'dotted'    =>	dotted line
#         'None' or ' ' or ''=>	draw nothing
#     legned : bool (default = False)
#         Set to 'True' to place a legend on the Axes.
# ...
